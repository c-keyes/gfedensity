# %%
# Example_6_10_15.ipynb
#
# Handling the special case of (l,m,n) = (6,10,15)
#
# Author: Christopher Keyes
# Updated 29 December 2025

load('gfedensity.sage')

# %%
# cleaning up presentation of l,m,n = 6,10,15

# compute rho
r, rA, rB, rC, rAB, rAC, rBC = get_probs(6,10,15)

# j,k = 1,1
num211 = (1-r)(gcd_pmin1_l_m = 2, gcd_pmin1_l_n = 1, gcd_pmin1_m_n = 1).factor().numerator()
den211 = (1-r)(gcd_pmin1_l_m = 2, gcd_pmin1_l_n = 1, gcd_pmin1_m_n = 1).factor().denominator()

# j,k = 3,1
num231 = (1-r)(gcd_pmin1_l_m = 2, gcd_pmin1_l_n = 3, gcd_pmin1_m_n = 1).factor().numerator()
den231 = (1-r)(gcd_pmin1_l_m = 2, gcd_pmin1_l_n = 3, gcd_pmin1_m_n = 1).factor().denominator()

# j,k = 1,5
num215 = (1-r)(gcd_pmin1_l_m = 2, gcd_pmin1_l_n = 1, gcd_pmin1_m_n = 5).factor().numerator()
den215 = (1-r)(gcd_pmin1_l_m = 2, gcd_pmin1_l_n = 1, gcd_pmin1_m_n = 5).factor().denominator()

# j,k = 3,5
num235 = (1-r)(gcd_pmin1_l_m = 2, gcd_pmin1_l_n = 3, gcd_pmin1_m_n = 5).factor().numerator()
den235 = (1-r)(gcd_pmin1_l_m = 2, gcd_pmin1_l_n = 3, gcd_pmin1_m_n = 5).factor().denominator()

# printing
print("(l,m,n) = (6,10,15)")
print()
print("(i,j,k) = (2,1,1): rho = 1 -")
print(num211)
print('/')
print(den211)
print()
print("(i,j,k) = (2,3,1): rho = 1 -")
print(num231)
print('/')
print(den231)
print()
print("(i,j,k) = (2,1,5): rho = 1 -")
print(num215)
print('/')
print(den215)
print()
print("(i,j,k) = (2,3,5): rho = 1 -")
print(num235)
print('/')
print(den235)
print()

print("Checking denominator of 1 - R_2jk is jk*(denom of 1-R_211), expect 0 0 0:", (den211*3 - den231).factor(),(den211*5 - den215).expand(),(den211*15 - den235).expand())
print()

print("Printing pretty for tex")
print("D(p) =")
print(latex(den211))
print()

print("S_1,1(p) =")
print(latex(num211))
print()

print("S_3,1(p) =")
print(latex(num231))
print()

print("S_1,5(p) =")
print(latex(num215))
print()

print("S_3,5(p) =")
print(latex(num235))
# Out:
# (l,m,n) = (6,10,15)
#
# (i,j,k) = (2,1,1): rho = 1 -
# p^72 + 2*p^71 + 13*p^70 + 14*p^69 + 26*p^68 + 27*p^67 + 47*p^66 + 46*p^65 + 72*p^64 + 70*p^63 + 102*p^62 + 98*p^61 + 135*p^60 + 128*p^59 + 163*p^58 + 146*p^57 + 188*p^56 + 179*p^55 + 214*p^54 + 197*p^53 + 234*p^52 + 217*p^51 + 247*p^50 + 230*p^49 + 254*p^48 + 230*p^47 + 259*p^46 + 245*p^45 + 257*p^44 + 236*p^43 + 247*p^42 + 220*p^41 + 233*p^40 + 205*p^39 + 215*p^38 + 190*p^37 + 193*p^36 + 162*p^35 + 171*p^34 + 143*p^33 + 137*p^32 + 107*p^31 + 112*p^30 + 84*p^29 + 86*p^28 + 57*p^27 + 49*p^26 + 32*p^25 + 27*p^24 + 5*p^23 - 2*p^22 - 10*p^21 - 17*p^20 - 23*p^19 - 27*p^18 - 29*p^17 - 37*p^16 - 32*p^15 - 33*p^14 - 21*p^13 - 26*p^12 - 21*p^11 - 19*p^10 - 10*p^9 - 15*p^8 - 10*p^7 - 8*p^6 - 4*p^5 - 6*p^4 - 2*p^3 - 2*p^2 - 2*p - 2
# /
# ...
